# %%
# Importer les packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Supprimer les warning
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### <font color = 'teal'>Importer et Lire les données<font>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# importer les données
# importer les données
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/Telephone_data.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Afficher les données
df.head()
# Out:
#      prix     adresse   marque  dim_ecr  ram  stockage        etat
# 0  580000  Guediawaye   iPhone      6.0    8       128  D'occasion
# 1  250000      Mermoz   iPhone      6.0    4       128  D'occasion
# 2   80000      Médina   iPhone      5.0    5       128  D'occasion
# 3  290000     Plateau  Samsung      6.0    8       256  D'occasion
# 4  250000      Mermoz  Samsung      6.0    8       256  D'occasion

# %% [markdown]
# #### <font color = "bisque">Concernant les données<font>
# Les données viennent de la page [coinafrique](http://sn.coinafrique.com/). L'objectif de la classification est de prédire si un portable est d'occasion, neuf, reconditionné ou venant en partant des caractéristiques suivant:
# * Prix
# * Adresse de vente
# * Marque
# * Dimension de l'écran
# * Nombre de ram
# * Stockage

# %%
# dimension des données
df.shape
# Out:
# (3253, 7)

# %%
# infos des données

# %% [markdown]
# ### <font color = 'gold'>Exploration des données<font>

# %% [markdown]
# ##### <font color = 'bisque'>Séléction des variables

# %%
# sélection des variables catégorielles en utilisant select_dtypes
cat_data = df.select_dtypes(include = 'object')
cat_data.head()
# Out:
#       adresse   marque        etat
# 0  Guediawaye   iPhone  D'occasion
# 1      Mermoz   iPhone  D'occasion
# 2      Médina   iPhone  D'occasion
# 3     Plateau  Samsung  D'occasion
# 4      Mermoz  Samsung  D'occasion

# %%
# sélection des variables quantitatives en utilisant select_dtypes
quant_data = df.select_dtypes(include = 'number')
quant_data.head()
# Out:
#      prix  dim_ecr  ram  stockage
# 0  580000      6.0    8       128
# 1  250000      6.0    4       128
# 2   80000      5.0    5       128
# 3  290000      6.0    8       256
# 4  250000      6.0    8       256

# %% [markdown]
# ##### <font color = 'bisque'> Exploration des variables catégorielles

# %%
# décrire les variables catégorielles
cat_data.describe().T
# Out:
#         count unique            top  freq
# adresse  3253     43        Plateau   415
# marque   3253     28         iPhone  1571
# etat     3253      4  Réconditionné  1053

# %%
# fonction de countplot
import plotly.express as px
def countplot_func(col):
  val = df[col].value_counts()
  # plt.figure(figsize=(25,3))
  fig = px.bar(x=val.index, y=val.values, color = val.index.astype(str), text_auto=True)
  fig.show()

# %%
# Countplots de toutes les variables
for col in cat_data.columns:
  countplot_func(col)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0df13cee-aa4c-47eb-9df0-dd6bcacd790b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0df13cee-aa4c-47eb-9df0-dd6bcacd790b")) {                    Plotly.newPlot(                        "0df13cee-aa4c-47eb-9df0-dd6bcacd790b",                        [{"alignmentgroup":"True","hovertemplate":"color=Plateau\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Plateau","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Plateau","offsetgroup":"Plateau","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Plateau"],"xaxis":"x","y":[415],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Médina\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Médina","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Médina","offsetgroup":"Médina","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Médina"],"xaxis":"x","y":[363],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Nord foire\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nord foire","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Nord foire","offsetgroup":"Nord foire","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Nord foire"],"xaxis":"x","y":[276],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Colobane\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colobane","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Colobane","offsetgroup":"Colobane","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Colobane"],"xaxis":"x","y":[253],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ngor\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ngor","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Ngor","offsetgroup":"Ngor","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Ngor"],"xaxis":"x","y":[201],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ouakam\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ouakam","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Ouakam","offsetgroup":"Ouakam","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Ouakam"],"xaxis":"x","y":[147],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Liberte 5\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Liberte 5","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Liberte 5","offsetgroup":"Liberte 5","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Liberte 5"],"xaxis":"x","y":[145],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Point-e\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Point-e","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Point-e","offsetgroup":"Point-e","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Point-e"],"xaxis":"x","y":[120],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Pikine\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pikine","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Pikine","offsetgroup":"Pikin ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="008e7cbe-79c8-478f-a0d5-58544982cbfd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("008e7cbe-79c8-478f-a0d5-58544982cbfd")) {                    Plotly.newPlot(                        "008e7cbe-79c8-478f-a0d5-58544982cbfd",                        [{"alignmentgroup":"True","hovertemplate":"color=iPhone\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"iPhone","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"iPhone","offsetgroup":"iPhone","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["iPhone"],"xaxis":"x","y":[1571],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Samsung\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Samsung","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Samsung","offsetgroup":"Samsung","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Samsung"],"xaxis":"x","y":[469],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=iPad\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"iPad","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"iPad","offsetgroup":"iPad","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["iPad"],"xaxis":"x","y":[412],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ZTE\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ZTE","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ZTE","offsetgroup":"ZTE","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["ZTE"],"xaxis":"x","y":[208],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Xiaomi\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Xiaomi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Xiaomi","offsetgroup":"Xiaomi","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Xiaomi"],"xaxis":"x","y":[154],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Google\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Google","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Google","offsetgroup":"Google","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Google"],"xaxis":"x","y":[83],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Huawei\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Huawei","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Huawei","offsetgroup":"Huawei","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Huawei"],"xaxis":"x","y":[81],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Honor\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Honor","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Honor","offsetgroup":"Honor","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honor"],"xaxis":"x","y":[34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Tecno\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tecno","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Tecno","offsetgroup":"Tecno","orientation":"v","showlegend":true,"textposition":"auto","texttemplate": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fffb8a89-eae9-4bcb-8572-3e24a320893d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fffb8a89-eae9-4bcb-8572-3e24a320893d")) {                    Plotly.newPlot(                        "fffb8a89-eae9-4bcb-8572-3e24a320893d",                        [{"alignmentgroup":"True","hovertemplate":"color=Réconditionné\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Réconditionné","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Réconditionné","offsetgroup":"Réconditionné","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Réconditionné"],"xaxis":"x","y":[1053],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Venant\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Venant","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Venant","offsetgroup":"Venant","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Venant"],"xaxis":"x","y":[779],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=D'occasion\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"D'occasion","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"D'occasion","offsetgroup":"D'occasion","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["D'occasion"],"xaxis":"x","y":[756],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Neuf\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neuf","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Neuf","offsetgroup":"Neuf","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Neuf"],"xaxis":"x","y":[665],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111 ...

# %% [markdown]
# ##### <font color = 'bisque'> Exploration des variables quantitatives

# %%
# décrire les variables quantitatives
quant_data.describe().T
# Out:
#            count           mean            std  min       25%       50%  \
# prix      3253.0  360830.307101  215801.003089  1.0  237043.0  362043.0
# dim_ecr   3253.0       6.510913       3.466092  0.0       6.0       6.0
# ram       3253.0      16.377498      20.291301  1.0      11.0      12.0
# stockage  3253.0     193.514294     169.625904  1.0     128.0     158.0
#
#                75%        max
# prix      462044.0  3335000.0
# dim_ecr        7.0       75.0
# ram           14.0      512.0
# stockage     256.0     5120.0

# %%
# pairplot
sns.pairplot(quant_data)
plt.show()

# %%
# matrice de corrélation
quant_data.corr()
# Out:
#               prix   dim_ecr       ram  stockage
# prix      1.000000  0.040199  0.159535  0.359586
# dim_ecr   0.040199  1.000000  0.024216  0.027186
# ram       0.159535  0.024216  1.000000  0.095711
# stockage  0.359586  0.027186  0.095711  1.000000

# %%
# matrice heatmap
sns.heatmap(quant_data.corr(), annot= True)
plt.show()

# %%
# fonction boxplots
def boxplot_func(col):
  plt.figure(figsize=(25,3))
  sns.boxplot(x=df[col])
  plt.show()

# %%
# boxplots des toutes les variables quantitatives
for col in quant_data.columns:
  boxplot_func(col)

# %% [markdown]
# ### <font color = 'gold'>Preparation des données<font>

# %% [markdown]
# ##### <font color = 'bisque'> Preparation des variables catégorielles

# %%
import joblib as jb
# Enregistrer les valeurs uniques des variables catégorielles dans un objet joblib
uniques = [] # [list_adresse, list_marque, list_etat]
for col in cat_data.columns:
  uniques.append(list(np.unique(df[col])))

# %%
# faire un dumping de la liste des valeurs uniques
jb.dump(uniques, '/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/uniques.joblib')
# Out:
# ['/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/uniques.joblib']

# %%
# Encoder les variables catégorielles
from sklearn.preprocessing import LabelEncoder

encoder0 = LabelEncoder() # objet encoder pour la variable adresse
encoder1 = LabelEncoder() # objet encoder pour la variable marque
encoder2 = LabelEncoder() # objet encoder pour la variable etat
encoders = [encoder0, encoder1, encoder2]
for i in range(len(cat_data.columns)):
  encoders[i].fit(df[cat_data.columns[i]]) # le modèle prend le temps de reconnaitre les classes
  df[cat_data.columns[i]] = encoders[i].transform(df[cat_data.columns[i]]) # encoder les valeurs

# %%
#address, marque, etat sont encodées
df.head()
# Out:
#      prix  adresse  marque  dim_ecr  ram  stockage  etat
# 0  580000       13      27      6.0    8       128     0
# 1  250000       22      27      6.0    4       128     0
# 2   80000       23      27      5.0    5       128     0
# 3  290000       32      19      6.0    8       256     0
# 4  250000       22      19      6.0    8       256     0

# %%
# faire un dumping (télécharger) de la liste des encodeurs
jb.dump(encoders, '/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/encoders.joblib')
# Out:
# ['/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/encoders.joblib']

# %% [markdown]
# ##### <font color = 'bisque'> Preparation des quantitatives

# %%
from sklearn.impute import KNNImputer

# fonction d'imputation des valeurs aberrantes
def impute_func(df, col, n_neighbors=3):
    # 2. Détection des outliers (Méthode IQR)
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    min_value = Q1 - 1.5 * IQR
    max_value = Q3 + 1.5 * IQR

    # Les valeurs hors bornes deviennent des valeurs manquantes pour le KNNImputer
    df.loc[(df[col] < min_value) | (df[col] > max_value), col] = np.nan
    # n_neighbors : nombre de voisins pour calculer la moyenne de remplacement
    imputer = KNNImputer(n_neighbors=n_neighbors)
    df[:] = imputer.fit_transform(df)

# %%
# Application du traitement
for col in quant_data.columns:
  impute_func(df,col)

# %%
# réafficher les boxplots
for col in quant_data.columns:
  boxplot_func(col)

# %%
# calculer la valeur minimale et valeur maximale
Q1 = df['ram'].quantile(0.25)
Q3 = df['ram'].quantile(0.75)
IQR = Q3 - Q1
min_value = Q1 - 1.5 * IQR
max_value = Q3 + 1.5 * IQR
# supprimer les nouvelles valeurs abérantes de la varibel ram
indexes = list(df.loc[(df['ram'] < min_value) | (df['ram'] > max_value), 'ram'].index)
df.drop(indexes, axis = 0, inplace =True)

# %% [markdown]
# ##### <font color = 'bisque'> Fractionnement et normalisation

# %%
# Fractionner les données en variables prédicteurs (x) et variable cibel(y)
x = df.iloc[:,:-1].values # variables d'entrées
y = df.iloc[:, -1].values # variable de sortie

# %%
# importer StandardScaler
from sklearn.preprocessing import StandardScaler
# Instancier StandardScaler
scaler = StandardScaler()
scaler.fit(x) # calcul de la moyenne et de l'écart type
x = scaler.transform(x) # normalisation

# %%
# faire un dumping (télécharger) du normaliseur
jb.dump(scaler, '/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/scaler.joblib')
# Out:
# ['/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/scaler.joblib']

# %%
# splitter les données en train, val et test
# train (80%), val(10%) et test(10%)
#train : données d'entrainement, val: données utiliser pour évaluer chaque modèle et test: données pour tester le modèle le plus performant
from sklearn.model_selection import train_test_split
x_train,x_vt, y_train, y_vt = train_test_split(x, y, train_size = 0.8 ,random_state = 42) # 80% / 20%
x_val,x_test, y_val, y_test = train_test_split(x_vt, y_vt, train_size = 0.5, random_state = 42) # 10% / 10%

# %%
# dimension des données train
x_train.shape, y_train.shape
# Out:
# ((2248, 6), (2248,))

# %%
# dimension des données de validation
x_val.shape, y_val.shape
# Out:
# ((281, 6), (281,))

# %%
# dimension des données test
x_test.shape, y_test.shape
# Out:
# ((282, 6), (282,))

# %% [markdown]
# ### <font color = 'teal'>Random Forest<font>

# %%
# Recherche des paramètres optimaux pour le Random Forest
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
# dictionnaire des  params
params = param_grid = {
    'n_estimators': list(np.arange(10,100,10)),
    'max_depth' : list(np.arange(3,15)),
    'criterion' :['gini', 'entropy']
}
# instantier le modèle Random Forest
rf = RandomForestClassifier()
# instantier le modèle gridsearch
grid = GridSearchCV(estimator=rf, param_grid=params, cv= 5)
# entrainer le modèle
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [np.int64(3), np.int64(4), np.int64(5),
#                                        np.int64(6), np.int64(7), np.int64(8),
#                                        np.int64(9), np.int64(10), np.int64(11),
#                                        np.int64(12), np.int64(13),
#                                        np.int64(14)],
#                          'n_estimators': [np.int64(10), np.int64(20),
#                                           np.int64(30), np.int64(40),
#                                           np.int64(50), np.int64(60),
#                                           np.int64(70), np.int64(80),
#                                           np.int64(90)]})

# %%
# Afficher les paramètres optimaux
best_params = grid.best_params_
best_params
# Out:
# {'criterion': 'gini', 'max_depth': np.int64(10), 'n_estimators': np.int64(60)}

# %%
# Entrainer Random Forest en utilisant les paramètres optimaux
rf_model = RandomForestClassifier(**best_params)
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=np.int64(10), n_estimators=np.int64(60))

# %% [markdown]
# ##### <font color ='bisque'>Evaluation du Random Forest<font>

# %%
# Accuracy et F1 score du modèle sur les données de validation
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
def evaluation(model):
  y_pred = model.predict(x_val)
  acc = accuracy_score(y_val, y_pred)
  f1 = f1_score(y_val, y_pred, average='micro')
  prec = precision_score(y_val, y_pred, average='micro')
  rec = recall_score(y_val, y_pred, average='micro')
  return acc, f1, prec, rec

# %%
# Afficher les métriques
acc_rf, f1_rf, prec_rf, rec_rf = evaluation(rf_model)
print(f"Accuracy : {acc_rf:.2f}-- F1 score : {f1_rf:.2f} -- Precision : {prec_rf:.2f} -- Recall : {rec_rf:.2f}")
# Out:
# Accuracy : 0.90-- F1 score : 0.90 -- Precision : 0.90 -- Recall : 0.90

# %%
# Accuracy sur les données train -- Vérifier le comportement du modèle en terme apprentissage
y_pred_train = rf_model.predict(x_train)
print(f"Le f1 score est : {f1_score(y_pred_train, y_train, average = 'micro'): .2f}")
# Out:
# Le f1 score est :  0.95

# %%
# Importer ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
def heatmap_conf_matr(model):

  # y_pred:  prédictions du modèle sur les données validation
  y_pred = model.predict(x_val)
  # Confusion matrix
  cnf_matr = confusion_matrix(y_val, y_pred, labels=[0,1,2,3])

  # Utiliser ConfusionMatrixDisplay pour visualiser la matrice de confusion
  disp = ConfusionMatrixDisplay(confusion_matrix=cnf_matr,
                                display_labels=['Occasion','Neuf', 'Reconditionné','Venant'])
  disp.plot() # Afficher la matrice de confusion
  plt.title('Matrice de confusion') # Définir le titre
  plt.show() # Afficher la figure

# %%
# visualiser
heatmap_conf_matr(rf_model)

# %%
# barplot de l'importance des variables
def barplot_impo(rf_model):
    fig = px.bar(x=df.columns[:-1], y=rf_model.feature_importances_, color = df.columns[:-1], text_auto=True)
    fig.show()

# %%
# faire appel de la fonction barplot_impo
barplot_impo(rf_model)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bc4cc8d3-ab5b-4311-8d13-a12090991899" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc4cc8d3-ab5b-4311-8d13-a12090991899")) {                    Plotly.newPlot(                        "bc4cc8d3-ab5b-4311-8d13-a12090991899",                        [{"alignmentgroup":"True","hovertemplate":"color=prix\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"prix","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"prix","offsetgroup":"prix","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["prix"],"xaxis":"x","y":[0.23074213161325688],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=adresse\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"adresse","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"adresse","offsetgroup":"adresse","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["adresse"],"xaxis":"x","y":[0.26893704244401145],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=marque\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"marque","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"marque","offsetgroup":"marque","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["marque"],"xaxis":"x","y":[0.10595961456792895],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=dim_ecr\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"dim_ecr","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"dim_ecr","offsetgroup":"dim_ecr","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["dim_ecr"],"xaxis":"x","y":[0.06169698984556666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ram\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ram","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ram","offsetgroup":"ram","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["ram"],"xaxis":"x","y":[0.03463763085991907],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=stockage\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"stockage","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"stockage","offsetgroup":"stockage","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["stockage"],"xaxis":"x","y":[0.29802659066931686],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"] ...

# %% [markdown]
# ### <font color = 'teal'>Gradient Boosting<font>

# %%
# Recherche des paramètres optimaux pour Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier
# dictionnaire des params
params_ = { "n_estimators":list(np.arange(10,100,10)),
              "max_depth":list(np.arange(3,15))}
# instantier le modèle Gradient Boost
gb = GradientBoostingClassifier()
# instantier le modèle gridsearch
grid_ = GridSearchCV(estimator=gb, param_grid=params_)
# entrainer le modèle
grid_.fit(x_train, y_train)

# %%
# afficher les paramètres optimaux
from sklearn.ensemble import GradientBoostingClassifier
gb_model = GradientBoostingClassifier(**grid_.best_params_)

# %%
# Entrainer Gradient Boosting en utilisant les paramètres optimaux max_depth = 5, n_estimators = 50
from sklearn.ensemble import GradientBoostingClassifier
gb_model = GradientBoostingClassifier(max_depth = 5, n_estimators = 50)
gb_model.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(max_depth=5, n_estimators=50)

# %% [markdown]
# ##### <font color ='bisque'>Evaluation du Gradient Boosting<font>

# %%
# Accuracy et F1 score du modèle sur les données de validation
acc_gb, f1_gb, prec_gb, rec_gb = evaluation(gb_model)
print(f"Accuracy : {acc_gb:.2f}-- F1 score : {f1_gb:.2f} -- Precision : {prec_gb:.2f} -- Recall : {rec_gb:.2f}")
# Out:
# Accuracy : 0.91-- F1 score : 0.91 -- Precision : 0.91 -- Recall : 0.91

# %%
# Accuracy sur les données train
y_pred_train = gb_model.predict(x_train)
print(f"Le f1 score est : {f1_score(y_pred_train, y_train, average = 'micro'): .2f}")
# Out:
# Le f1 score est :  0.93

# %%
# matrice de confusion
heatmap_conf_matr(gb_model)

# %%
# barplot de l'importance des variables
barplot_impo(gb_model)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7c324416-2c32-4ab6-867a-cfc2eebea511" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c324416-2c32-4ab6-867a-cfc2eebea511")) {                    Plotly.newPlot(                        "7c324416-2c32-4ab6-867a-cfc2eebea511",                        [{"alignmentgroup":"True","hovertemplate":"color=prix\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"prix","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"prix","offsetgroup":"prix","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["prix"],"xaxis":"x","y":[0.13261868673968602],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=adresse\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"adresse","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"adresse","offsetgroup":"adresse","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["adresse"],"xaxis":"x","y":[0.08949449265272491],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=marque\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"marque","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"marque","offsetgroup":"marque","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["marque"],"xaxis":"x","y":[0.06223255756243888],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=dim_ecr\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"dim_ecr","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"dim_ecr","offsetgroup":"dim_ecr","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["dim_ecr"],"xaxis":"x","y":[0.027095010393820028],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ram\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ram","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ram","offsetgroup":"ram","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["ram"],"xaxis":"x","y":[0.02769194650067864],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=stockage\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"stockage","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"stockage","offsetgroup":"stockage","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["stockage"],"xaxis":"x","y":[0.6608673061506515],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"] ...

# %% [markdown]
# ### <font color = 'teal'>XGBoost<font>

# %%
# Recherche des paramètres optimaux pour XGBoost
from xgboost import XGBClassifier
# dictionnaire des params
params__ = {  "n_estimators":list(np.arange(10,100,10)),
              "max_depth":list(np.arange(3,15))}
# instantier le modèle XGBoost
xgb = XGBClassifier()
# instantier le modèle gridsearch
grid__ = GridSearchCV(estimator=xgb, param_grid=params__, cv= 5)
# entrainer le modèle
grid__.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=True, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None...
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'max_depth': [np.int64(3), np.int64(4), np.int64(5),
#                                        np.int64(6), np.int64(7), np.int64(8),
#                                        np.int64(9), np.int64(10), np.int64(11),
#                                        np.int64(12), np.int64(13),
#                                        np.int64(14)],
#                          'n_estimators': [np.int64(10), np.int64(20),
#                                           np.int64(30), np.int64(40),
#                                           np.int64(50), np.int64(60),
#                                           np.int64(70), np.int64(80),
#                                           np.int64(90)]})

# %%
# afficher les paramètres optimaux
params = grid__.best_params_

# %%
# Entrainer le modèle en utilisant les paramètres optimaux
xgb_model = XGBClassifier(**params)
xgb_model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None,
#               max_depth=np.int64(5), max_leaves=None, min_child_weight=None,
#               missing=nan, monotone_constraints=None, multi_strategy=None,
#               n_estimators=np.int64(20), n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ##### <font color ='bisque'>Evaluation de XGBoost<font>

# %%
# Accuracy et F1 score du modèle sur les données de validation
acc_xgb, f1_xgb, prec_xgb, rec_xgb = evaluation(xgb_model)
print(f"Accuracy : {acc_xgb:.2f}-- F1 score : {f1_xgb:.2f} -- Precision : {prec_xgb:.2f} -- Recall : {rec_xgb:.2f}")
# Out:
# Accuracy : 0.91-- F1 score : 0.91 -- Precision : 0.91 -- Recall : 0.91

# %%
# Accuracy sur les données train
y_pred_train = xgb_model.predict(x_train)
print(f"Le f1 score est : {f1_score(y_pred_train, y_train, average = 'micro'): .2f}")
# Out:
# Le f1 score est :  0.91

# %%
# matrice de confusion
heatmap_conf_matr(gb_model)

# %%
# barplot de l'importance des variables
barplot_impo(xgb_model)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5aaf9c0c-3d8c-4f31-8feb-ebca9732a566" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5aaf9c0c-3d8c-4f31-8feb-ebca9732a566")) {                    Plotly.newPlot(                        "5aaf9c0c-3d8c-4f31-8feb-ebca9732a566",                        [{"alignmentgroup":"True","hovertemplate":"color=prix\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"prix","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"prix","offsetgroup":"prix","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["prix"],"xaxis":"x","y":[0.073973045],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=adresse\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"adresse","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"adresse","offsetgroup":"adresse","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["adresse"],"xaxis":"x","y":[0.068110526],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=marque\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"marque","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"marque","offsetgroup":"marque","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["marque"],"xaxis":"x","y":[0.086176075],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=dim_ecr\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"dim_ecr","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"dim_ecr","offsetgroup":"dim_ecr","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["dim_ecr"],"xaxis":"x","y":[0.21611509],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=ram\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ram","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ram","offsetgroup":"ram","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["ram"],"xaxis":"x","y":[0.09141843],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=stockage\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"stockage","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"stockage","offsetgroup":"stockage","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["stockage"],"xaxis":"x","y":[0.46420684],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222 ...

# %%
# Diagramme en barre de comparaison des modèles
list_f1 = [f1_rf, f1_gb, f1_xgb]
list_models_name = ['RF', 'GB', 'XGB']
fig = px.bar(x=list_models_name, y=list_f1, color = list_models_name, text_auto=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="877ef15f-48bd-4213-8cb1-fb48a63e5880" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("877ef15f-48bd-4213-8cb1-fb48a63e5880")) {                    Plotly.newPlot(                        "877ef15f-48bd-4213-8cb1-fb48a63e5880",                        [{"alignmentgroup":"True","hovertemplate":"color=RF\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RF","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"RF","offsetgroup":"RF","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["RF"],"xaxis":"x","y":[0.896797153024911],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=GB\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GB","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"GB","offsetgroup":"GB","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["GB"],"xaxis":"x","y":[0.9145907473309609],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=XGB\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"XGB","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"XGB","offsetgroup":"XGB","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["XGB"],"xaxis":"x","y":[0.9145907473309609],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e" ...

# %%
# télécharger le modèle le plus performant
jb.dump(xgb_model, '/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/xgb_model.joblib')
# Out:
# ['/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/xgb_model.joblib']

# %% [markdown]
# ### <font color ='bisque'>Tester le modèle le plus performant<font>

# %%
#chantilon de 10 
x_test_10 = x_test[:10]
y_test_10 = y_test[:10]
y_pred_10 = xgb_model.predict(x_test_10)
class_names = ['Ocassion','Neuf', 'Reconditionné','Venant']
for i in range(10):
  print(f"Le téléphone {i+1} est : {class_names[y_pred_10[i]]} | Vrai : {class_names[y_test_10[i]]}")
# Out:
# Le téléphone 1 est : Venant | Vrai : Venant
# Le téléphone 2 est : Ocassion | Vrai : Ocassion
# Le téléphone 3 est : Ocassion | Vrai : Ocassion
# Le téléphone 4 est : Ocassion | Vrai : Ocassion
# Le téléphone 5 est : Reconditionné | Vrai : Reconditionné
# Le téléphone 6 est : Reconditionné | Vrai : Reconditionné
# Le téléphone 7 est : Reconditionné | Vrai : Reconditionné
# Le téléphone 8 est : Venant | Vrai : Venant
# Le téléphone 9 est : Ocassion | Vrai : Ocassion
# Le téléphone 10 est : Venant | Vrai : Venant

# %% [markdown]
# ### <font color = 'bisque'>Deploiement du modèle avec Gradio<font>

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (6.20.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.14.2)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.139.0)
# Requirement already satisfied: gradio-client==2.5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.5.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.4.1)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.23.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio) (26.2)
# Requirement already satisfied: pandas<4.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<13.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.13.4)
# Requirement already satisfied: pydub<1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.32)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.3.1)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.14.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.26.8)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.16.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.51.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==2.5.0->gradio) (2025.3.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (3.18)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (3.29.7)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (1.5.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=1.0->gradio) (2026.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=3.0,>=2.0->gradio) (2.46.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
# Fonction de prédiction
import gradio as gr
import joblib as jb
import numpy as np
import pandas as pd
# importer les encodeurs
encoders = jb.load('/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/encoders.joblib')
# importer les valeurs uniques
uniques = jb.load('/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/uniques.joblib')
# importer le normaliseur
scaler = jb.load('/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/scaler.joblib')
# importer le modèle
xgb = jb.load('/content/drive/MyDrive/karaguaIA/Supervised Learning /Classification/xgb_model.joblib')

# noms des classes
clasnames = uniques[2]
# fonction de prédiction simple
def Pred_func(prix, adresse, marque,dim_ecr, ram, stockage):

  # Encoder les valeurs des Fuel_Type, Seller_Type et Transmission
  adresse = encoders[0].transform([adresse])[0]
  marque = encoders[1].transform([marque])[0]
  # vecteur des valeurs numériques
  x_new = np.array([prix, adresse, marque,dim_ecr, ram, stockage])
  x_new = x_new.reshape(1,-1) # convert en un 2D array
  # Normaliser les données
  x_new = scaler.transform(x_new)
  # Prédire
  y_pred = xgb.predict(x_new)
  return clasnames[y_pred[0]]

# %%
# Fonction de prédiction multiple
def Pred_func_csv(file):
  # Lire le fichier csv
  df = pd.read_csv(file)
  predictions = []
  # Boucle sur les lignes du dataframe
  for row in df.iloc[:, :].values:
    # prédiction simple
    y_pred = Pred_func(row[0], row[1], row[2], row[3], row[4], row[5])
    predictions.append(y_pred)

  df['etat'] = predictions
  df.to_csv('predictions.csv', index = False)
  return 'predictions.csv'

# %%
# définir les blocks
demo = gr.Blocks(theme='shivi/calm_seafoam')

# Créer les inputs
inputs = [gr.Number(label='Prix'),
          gr.Dropdown(choices=uniques[0], label='Adresse'),
          gr.Dropdown(choices=uniques[1], label='Marque'),
          gr.Number(label='Dimensin écran'),
          gr.Number(label='Nombre de ram'),
          gr.Number(label = 'Stockage')]
# Créer les outputs
outputs = gr.Textbox(label='Etat du portable')
# Créer l'interface 1
interface1 = gr.Interface(fn = Pred_func,
                         inputs = inputs,
                         outputs = outputs,
                         title="Prédire l'état d'un portable avec une entrée",
                         description = """Ce modèle de machine permet de prédire l'état d'un portable en partant
                        du prix, l'adresse, la marque, la dimension de l'écran, le nombre de ram et le stockage.
                         """)
# Créer l'interface 2
interface2 = gr.Interface(fn = Pred_func_csv,
                         inputs = gr.File(label='Importer un fichier csv'),
                          outputs = gr.File(label='Télécharger un fichier csv'),
                         title="Prédire l'état d'un portable avec plusieurs entrées",
                         description = """Ce modèle de machine permet de prédire l'état d'un portable en partant
                        du prix, l'adresse, la marque, la dimension de l'écran, le nombre de ram et le stockage.
                         """)

# faire un tabbing des interfaces
with demo:
  gr.TabbedInterface([interface1, interface2], ['Simple Prediction', 'Prédiction multiple'])

# lancer l'interface
demo.launch(share=True)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# theme_schema%400.0.1.json:   0%|          | 0.00/13.0k [00:00<?, ?B/s]
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://13338baf7c9616c247.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://13338baf7c9616c247.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
